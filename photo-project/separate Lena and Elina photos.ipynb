# %%
import numpy as np
from scipy import linalg
import scipy.signal as signal
import matplotlib.image as mpimg
import matplotlib as mpl
cmap = mpl.cm.gray_r
import pylab
import random
import matplotlib.pyplot as plt
from PIL import Image
#In this experiment, I separated Lena and Elina 
#The source photos I had were two mixed pictures, they were named as image1.png and image2.png
#Using ICA algorithm, I successfuly separated rather puried Lena and Elina

# %%
def show_data(T, S):
    plt.plot(T, [S[0,i] for i in range(S.shape[1])], marker="*")
    plt.plot(T, [S[1,i] for i in range(S.shape[1])], marker="o")
    plt.show()

# %%
p1 = mpimg.imread('image1.png')#show original mixed photo1
plt.imshow(p1)
p1 = np.reshape(p1,(512*512,1))
plt.axis('off')
plt.show()

# %%
p2 = mpimg.imread('image2.png')#show oroginal mixed photo2
plt.imshow(p2)
p2 = np.reshape(p2,(512*512,1))
plt.axis('off')
plt.show()

# %%
p = np.append(p1, p2,axis=-1)
p = p.T
T = [i for i in range(0, 262144)]

# %%
def Whitening(X):
    #normalize X
    mean = X.mean(axis=-1)
    n = np.shape(X)
    for i in range(0,n[0]):
        for j in range(0,n[1]):
            X[i][j] = X[i][j] - mean[i]
    #whitening X to get z
    sigma = np.dot(X,X.T)
    d,E = linalg.eig(sigma)
    D = np.diag(1/d)
    V = np.dot(D,E.T)
    z = np.dot(V,X)
    return z

# %%
z = Whitening(p)
print("Shape of z is",np.shape(z))
#show_data(T,z)#show z1 & z2
# Out:
# Shape of z is (2, 262144)

# %%
def Decorrelation(W):#W <- (W*W.T)^(-0.5)*W to make W decorrelated
    d, e = linalg.eigh(np.dot(W, W.T))
    return np.dot(np.dot(e * (1. / np.sqrt(d)), e.T), W)

#I try a lot when w is [[ 0.7768532   0.38323983] [ 0.21723714  0.66516969]]
# it can get a good result of one of the source as source1
def Gerneratew(z):
    m = np.shape(z)[0]#use random (m,m) to make z 
    n = np.shape(z)[1]
    W = np.random.rand(m,m)
    W[0][0] =  0.7768532
    W[0][1] =  0.38323983
    W[1][0] = 0.21723714
    W[1][1] = 0.66516969
    print("Now we Generate Good W as",W)
    lim = 200
    for i in range(0,m):
        while lim > 0.00001:
            W[i] = W[i]/np.linalg.norm(W[i])
            Wold = W
            y = np.dot(W[i][:,np.newaxis],z[0][:, np.newaxis].T)
            W[i] = (z[i] * pow(y[0],3)).mean(axis=-1) - 3*W[i]
            W[i] = W[i]/np.linalg.norm(W[i])
            W = Decorrelation(W)
            lim = max( abs(abs(np.dot(W[i],Wold[i][:,np.newaxis])) - 1) )#vdo
    lim = 200
    while lim > 0.0001:
        Wold = W
        W = Decorrelation(W)
        lim = max( abs(abs(np.diag(np.dot(W, Wold.T))) - 1) )

    print("We did it!!!")    
    return W

# %%
W = Gerneratew(z)#record the W when get good W
# Out:
# Now we Generate Good W as [[0.7768532  0.38323983]
#  [0.21723714 0.66516969]]
# We did it!!!
# /Users/lingchensanwen/anconda-new/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:22: ComplexWarning: Casting complex values to real discards the imaginary part

# %%
y = np.dot(W,z)

# %%
#show_data(T,y)

# %%
#plt.plot(T, [y[0,i] for i in range(y.shape[1])], marker="*")
#plt.show()

# %%
#plt.plot(T, [y[1,i] for i in range(y.shape[1])], marker="*")
#plt.show()

# %%
s1 = np.reshape(y[0],(512,512))

# %%
s2 = np.reshape(y[1],(512,512))

# %%
p1 = mpimg.imread('image1.png')
for i in range(0,512):
    for j in range(0,512):
        p1[i][j] = s1[i][j] 
#plt.imshow(p1)
#plt.axis('off')
#plt.show()
#plt.imsave('p1.png', p1)
# Out:
# /Users/lingchensanwen/anconda-new/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: ComplexWarning: Casting complex values to real discards the imaginary part
#   after removing the cwd from sys.path.

# %%
p2 = mpimg.imread('image2.png') #Result source Lena
for i in range(0,512):
    for j in range(0,512):
        p2[i][j] = s2[i][j]
plt.imshow(p2)
plt.axis('off')
plt.show()
plt.imshow(p2, plt.cm.gray_r)
plt.imsave('source1.png', p2, cmap = plt.cm.gray_r)
# Out:
# /Users/lingchensanwen/anconda-new/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: ComplexWarning: Casting complex values to real discards the imaginary part
#   after removing the cwd from sys.path.

# %%
    W[0][0] = 0.7768532   #adjust W to separate good Elina source photo
    W[0][1] = 0.38323983
    W[1][0] = 0.21723714
    W[1][1] = 0.66516969

# %%
y = np.dot(W,z)

# %%
s1 = np.reshape(y[0],(512,512)) # Result source Elina 
s2 = np.reshape(y[1],(512,512))
p2 = mpimg.imread('image2.png')
for i in range(0,512):
    for j in range(0,512):
        p2[i][j] = s2[i][j]
plt.imshow(p2)
plt.axis('off')
plt.show()
plt.imshow(p2, plt.cm.gray_r)
plt.imsave('source1.png', p2, cmap = plt.cm.gray_r)
# Out:
# /Users/lingchensanwen/anconda-new/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: ComplexWarning: Casting complex values to real discards the imaginary part
